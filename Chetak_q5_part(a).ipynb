# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 720.1/720.1 kB 10.0 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="XQrsPX46uIp0xk3xUr5S")
project = rf.workspace("zabidas-yt-byjrg").project("cardetect-09aer")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.yaml')
results = model.train(data= '/content/CarDetect-1/data.yaml', epochs=300)
results = model.val()
success = model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.1.25 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.predict('/content/car(1).jpg')
# Out:
# image 1/1 /content/car(1).jpg: 640x384 1 0, 104.6ms
# Speed: 3.0ms preprocess, 104.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: '0', 1: 'car', 2: 'cars'}
#  obb: None
#  orig_img: array([[[ 39,  39,  39],
#          [ 33,  33,  33],
#          [ 40,  40,  40],
#          ...,
#          [205, 205, 205],
#          [205, 205, 205],
#          [205, 205, 205]],
#
#         [[ 41,  41,  41],
#          [ 40,  40,  40],
#          [ 50,  50,  50],
#          ...,
#          [205, 205, 205],
#          [205, 205, 205],
#          [205, 205, 205]],
#
#         [[ 39,  39,  39],
#          [ 37,  37,  37],
#          [ 46,  46,  46],
#          ...,
#          [205, 205, 205],
#          [205, 205, 205],
#          [205, 205, 205]],
#
#         ...,
#
#         [[106, 106, 106],
#          [108, 108, 108],
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow


model = YOLO('/content/runs/detect/train/weights/last.pt')

image = cv2.imread('/content/asd.jpg')
image = cv2.resize(image, (416, 416))

results = model.predict(image)
print(results[0].boxes.xyxy.tolist())

for box in results[0][0].boxes.xyxy.tolist():
    xB = int(box[2])
    xA = int(box[0])
    yB = int(box[3])
    yA = int(box[1])

    cv2.rectangle(image, (xA, yA), (xB, yB), (0, 255, 0), 2)
cv2_imshow(image)
# Out:
# 0: 640x640 1 0, 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# [[1.4888824224472046, 159.75308227539062, 108.56576538085938, 280.0171203613281]]
# <PIL.Image.Image image mode=RGB size=416x416>
